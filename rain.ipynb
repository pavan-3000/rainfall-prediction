# %%
import pandas as  pd

# %%
rain = pd.read_csv("/home/snow/Downloads/Rainfall_Prediction-Using-ML_Flask-master/Daily_Sub-basin-wise_Rainfall_data_from_National_Remote_Sensing_Centre_Agency_during_October_2023.csv")

# %%
rain.head()
# Out:
#                                         Basin  \
# 0  Area of Inland drainage in Rajasthan Basin
# 1  Area of Inland drainage in Rajasthan Basin
# 2  Area of Inland drainage in Rajasthan Basin
# 3  Area of Inland drainage in Rajasthan Basin
# 4  Area of Inland drainage in Rajasthan Basin
#
#                                Subbasin        Date  Year  Month  \
# 0  Area of Inland drainage in Rajasthan  2023-10-01  2023     10
# 1  Area of Inland drainage in Rajasthan  2023-10-07  2023     10
# 2  Area of Inland drainage in Rajasthan  2023-10-08  2023     10
# 3  Area of Inland drainage in Rajasthan  2023-10-09  2023     10
# 4  Area of Inland drainage in Rajasthan  2023-10-10  2023     10
#
#    Avg_rainfall     Agency_name
# 0           NaN  NRSC VIC MODEL
# 1           NaN  NRSC VIC MODEL
# 2           NaN  NRSC VIC MODEL
# 3           NaN  NRSC VIC MODEL
# 4      0.028506  NRSC VIC MODEL

# %%
rain.shape
# Out:
# (2280, 7)

# %%
rain.columns
# Out:
# Index(['Basin', 'Subbasin', 'Date', 'Year', 'Month', 'Avg_rainfall',
#        'Agency_name'],
#       dtype='object')

# %%
ind = pd.read_csv("/home/snow/Downloads/Rainfall_Prediction-Using-ML_Flask-master/district wise rainfall normal.csv")

# %%
ind.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#    Mar-May  Jun-Sep  Oct-Dec
# 0    540.7   1207.2    892.1
# ...

# %%
df = pd.read_csv("/home/snow/Downloads/Rainfall_Prediction-Using-ML_Flask-master/testing_notebooks/weatherAUS.csv")

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
ind.shape,df.shape
# Out:
# ((641, 19), (145460, 23))

# %%
df = df.drop('Location',axis=1)

# %%
df['Location'] = ind['STATE_UT_NAME']

# %%
ind['MinTemp'] = df['MinTemp']

# %%
ind.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#    Mar-May  Jun-Sep  Oct-Dec  MinTemp
# ...

# %%
final = ind[['STATE_UT_NAME','MinTemp']]

# %%
final.head()
# Out:
#                  STATE_UT_NAME  MinTemp
# 0  ANDAMAN And NICOBAR ISLANDS     13.4
# 1  ANDAMAN And NICOBAR ISLANDS      7.4
# 2  ANDAMAN And NICOBAR ISLANDS     12.9
# 3            ARUNACHAL PRADESH      9.2
# 4            ARUNACHAL PRADESH     17.5

# %%
final.dropna(inplace=True)
# Out:
# /home/snow/Downloads/Rainfall_Prediction-Using-ML_Flask-master/rainfall/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final.head()
final.shape
# Out:
# (636, 2)

# %%
final['RainToday'] = df['RainToday']
# Out:
# /home/snow/Downloads/Rainfall_Prediction-Using-ML_Flask-master/rainfall/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final.head()
# Out:
#                  STATE_UT_NAME  MinTemp        Date  MaxTemp  Humidity  \
# 0  ANDAMAN And NICOBAR ISLANDS     13.4  2008-12-01     22.9      22.0
# 1  ANDAMAN And NICOBAR ISLANDS      7.4  2008-12-02     25.1      25.0
# 2  ANDAMAN And NICOBAR ISLANDS     12.9  2008-12-03     25.7      30.0
# 3            ARUNACHAL PRADESH      9.2  2008-12-04     28.0      16.0
# 4            ARUNACHAL PRADESH     17.5  2008-12-05     32.3      33.0
#
#    Pressure RainToday
# 0    1007.7        No
# 1    1010.6        No
# 2    1007.6        No
# 3    1017.6        No
# 4    1010.8        No

# %%
final.dropna(inplace=True)
# Out:
# /home/snow/Downloads/Rainfall_Prediction-Using-ML_Flask-master/rainfall/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final.shape
# Out:
# (626, 7)

# %%
df.head()
# Out:
#          Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  2008-12-01     13.4     22.9       0.6          NaN       NaN           W
# 1  2008-12-02      7.4     25.1       0.0          NaN       NaN         WNW
# 2  2008-12-03     12.9     25.7       0.0          NaN       NaN         WSW
# 3  2008-12-04      9.2     28.0       0.0          NaN       NaN          NE
# 4  2008-12-05     17.5     32.3       1.0          NaN       NaN           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity3pm  Pressure9am  \
# 0           44.0          W        WNW  ...         22.0       1007.7
# 1           44.0        NNW        WSW  ...         25.0       1010.6
# 2           46.0          W        WSW  ...         30.0       1007.6
# 3           24.0         SE          E  ...         16.0       1017.6
# 4           41.0        ENE         NW  ...         33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  \
# ...

# %%
final.to_csv('indiarain.csv',index=False)

# %%
final = df['Location'].dropna()

# %%
df.isna().sum()
# Out:
# Date                  0
# MinTemp            1485
# MaxTemp            1261
# Rainfall           3261
# Evaporation       62790
# Sunshine          69835
# WindGustDir       10326
# WindGustSpeed     10263
# WindDir9am        10566
# WindDir3pm         4228
# WindSpeed9am       1767
# WindSpeed3pm       3062
# Humidity9am        2654
# Humidity3pm        4507
# Pressure9am       15065
# Pressure3pm       15028
# Cloud9am          55888
# Cloud3pm          59358
# Temp9am            1767
# Temp3pm            3609
# RainToday          3261
# RainTomorrow       3267
# Location         144819
# dtype: int64

# %%
final = df.dropna()

# %%
final
# Out:
# Empty DataFrame
# Columns: [Date, MinTemp, MaxTemp, Rainfall, Evaporation, Sunshine, WindGustDir, WindGustSpeed, WindDir9am, WindDir3pm, WindSpeed9am, WindSpeed3pm, Humidity9am, Humidity3pm, Pressure9am, Pressure3pm, Cloud9am, Cloud3pm, Temp9am, Temp3pm, RainToday, RainTomorrow, Location]
# Index: []
#
# [0 rows x 23 columns]

# %%
final.head()
# Out:
#                  STATE_UT_NAME  MinTemp        Date  MaxTemp  Humidity  \
# 0  ANDAMAN And NICOBAR ISLANDS     13.4  2008-12-01     22.9      22.0
# 1  ANDAMAN And NICOBAR ISLANDS      7.4  2008-12-02     25.1      25.0
# 2  ANDAMAN And NICOBAR ISLANDS     12.9  2008-12-03     25.7      30.0
# 3            ARUNACHAL PRADESH      9.2  2008-12-04     28.0      16.0
# 4            ARUNACHAL PRADESH     17.5  2008-12-05     32.3      33.0
#
#    Pressure
# 0    1007.7
# 1    1010.6
# 2    1007.6
# 3    1017.6
# 4    1010.8

# %%
final.columns
# Out:
# Index(['STATE_UT_NAME', 'MinTemp', 'Date', 'MaxTemp', 'Humidity', 'Pressure',
#        'RainToday'],
#       dtype='object')

# %%
def split_date(date_str):
    year, month, day = date_str.split('-')
    return int(year), int(month), int(day)

# Apply the function to the 'date' column
final[['year', 'month', 'day']] = final['Date'].apply(lambda x: pd.Series(split_date(x)))

# Display the DataFrame
print(final.head())
# Out:
#                  STATE_UT_NAME  MinTemp        Date  MaxTemp  Humidity  \
# 0  ANDAMAN And NICOBAR ISLANDS     13.4  2008-12-01     22.9      22.0
# 1  ANDAMAN And NICOBAR ISLANDS      7.4  2008-12-02     25.1      25.0
# 2  ANDAMAN And NICOBAR ISLANDS     12.9  2008-12-03     25.7      30.0
# 3            ARUNACHAL PRADESH      9.2  2008-12-04     28.0      16.0
# 4            ARUNACHAL PRADESH     17.5  2008-12-05     32.3      33.0
#
#    Pressure RainToday  year  month  day
# 0    1007.7        No  2008     12    1
# 1    1010.6        No  2008     12    2
# 2    1007.6        No  2008     12    3
# 3    1017.6        No  2008     12    4
# 4    1010.8        No  2008     12    5
# /home/snow/Downloads/Rainfall_Prediction-Using-ML_Flask-master/rainfall/lib/python3.6/site-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
final.head()
# Out:
#                  STATE_UT_NAME  MinTemp        Date  MaxTemp  Humidity  \
# 0  ANDAMAN And NICOBAR ISLANDS     13.4  2008-12-01     22.9      22.0
# 1  ANDAMAN And NICOBAR ISLANDS      7.4  2008-12-02     25.1      25.0
# 2  ANDAMAN And NICOBAR ISLANDS     12.9  2008-12-03     25.7      30.0
# 3            ARUNACHAL PRADESH      9.2  2008-12-04     28.0      16.0
# 4            ARUNACHAL PRADESH     17.5  2008-12-05     32.3      33.0
#
#    Pressure RainToday  year  month  day
# 0    1007.7        No  2008     12    1
# 1    1010.6        No  2008     12    2
# 2    1007.6        No  2008     12    3
# 3    1017.6        No  2008     12    4
# 4    1010.8        No  2008     12    5

# %%
final.drop("Date",axis=1)
# Out:
#      STATE_UT_NAME  MinTemp  MaxTemp  Humidity  Pressure RainToday  year  \
# 0                0     13.4     22.9      22.0    1007.7        No  2008
# 1                0      7.4     25.1      25.0    1010.6        No  2008
# 2                0     12.9     25.7      30.0    1007.6        No  2008
# 3                2      9.2     28.0      16.0    1017.6        No  2008
# 4                2     17.5     32.3      33.0    1010.8        No  2008
# ..             ...      ...      ...       ...       ...       ...   ...
# 636             17      1.9     15.2      57.0    1029.6        No  2010
# 637             17      2.3     15.4      51.0    1028.9        No  2010
# 638             17      2.9     14.2      61.0    1024.8        No  2010
# 639             17      7.1     15.1      71.0    1015.8        No  2010
# 640             18     10.0     16.8      68.0    1016.5        No  2010
#
#      month  day
# 0       12    1
# 1       12    2
# 2       12    3
# 3       12    4
# ...

# %%
final.isna().sum()
# Out:
# STATE_UT_NAME    0
# MinTemp          0
# Date             0
# MaxTemp          0
# Humidity         0
# Pressure         0
# RainToday        0
# year             0
# month            0
# day              0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder() 
final['STATE_UT_NAME']= encoder.fit_transform(final['STATE_UT_NAME'])
# Out:
# /home/snow/Downloads/Rainfall_Prediction-Using-ML_Flask-master/rainfall/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
final.head()
# Out:
#    STATE_UT_NAME  MinTemp        Date  MaxTemp  Humidity  Pressure RainToday  \
# 0              0     13.4  2008-12-01     22.9      22.0    1007.7        No
# 1              0      7.4  2008-12-02     25.1      25.0    1010.6        No
# 2              0     12.9  2008-12-03     25.7      30.0    1007.6        No
# 3              2      9.2  2008-12-04     28.0      16.0    1017.6        No
# 4              2     17.5  2008-12-05     32.3      33.0    1010.8        No
#
#    year  month  day
# 0  2008     12    1
# 1  2008     12    2
# 2  2008     12    3
# 3  2008     12    4
# 4  2008     12    5

# %%
final = final.drop('Date',axis=1)

# %%
encoder = LabelEncoder() 
final['RainToday']= encoder.fit_transform(final['RainToday'])

# %%
final.head()
# Out:
#    STATE_UT_NAME  MinTemp  MaxTemp  Humidity  Pressure RainToday  year  month  \
# 0              0     13.4     22.9      22.0    1007.7        No  2008     12
# 1              0      7.4     25.1      25.0    1010.6        No  2008     12
# 2              0     12.9     25.7      30.0    1007.6        No  2008     12
# 3              2      9.2     28.0      16.0    1017.6        No  2008     12
# 4              2     17.5     32.3      33.0    1010.8        No  2008     12
#
#    day
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5

# %%
final

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 626 entries, 0 to 640
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_UT_NAME  626 non-null    int64
#  1   MinTemp        626 non-null    float64
#  2   MaxTemp        626 non-null    float64
#  3   Humidity       626 non-null    float64
#  4   Pressure       626 non-null    float64
#  5   RainToday      626 non-null    object
#  6   year           626 non-null    int64
#  7   month          626 non-null    int64
#  8   day            626 non-null    int64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 48.9+ KB

# %%
X = final.drop(["RainToday"], axis=1)
Y = final["RainToday"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size =0.2, random_state = 42)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier

# %%
cat = CatBoostClassifier(iterations=2000, eval_metric = "AUC")
cat.fit(X_train, y_train)
# Out:
# Learning rate set to 0.004058
# 0:	total: 59.4ms	remaining: 1m 58s
# 1:	total: 64ms	remaining: 1m 3s
# 2:	total: 68.5ms	remaining: 45.6s
# 3:	total: 70.8ms	remaining: 35.3s
# 4:	total: 72.6ms	remaining: 29s
# 5:	total: 77.8ms	remaining: 25.9s
# 6:	total: 85ms	remaining: 24.2s
# 7:	total: 89.6ms	remaining: 22.3s
# 8:	total: 94.9ms	remaining: 21s
# 9:	total: 99.2ms	remaining: 19.7s
# 10:	total: 102ms	remaining: 18.4s
# 11:	total: 103ms	remaining: 17.1s
# 12:	total: 108ms	remaining: 16.5s
# 13:	total: 110ms	remaining: 15.6s
# 14:	total: 111ms	remaining: 14.7s
# 15:	total: 114ms	remaining: 14.1s
# 16:	total: 115ms	remaining: 13.4s
# 17:	total: 116ms	remaining: 12.8s
# 18:	total: 118ms	remaining: 12.3s
# 19:	total: 121ms	remaining: 11.9s
# 20:	total: 124ms	remaining: 11.6s
# 21:	total: 126ms	remaining: 11.3s
# 22:	total: 127ms	remaining: 10.9s
# 23:	total: 128ms	remaining: 10.5s
# 24:	total: 129ms	remaining: 10.2s
# 25:	total: 130ms	remaining: 9.87s
# 26:	total: 131ms	remaining: 9.57s
# ...

# %%
y_pred4 = cat.predict(X_test)

# %%
metrics.roc_auc_score(y_test, y_pred4, average=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-cf33fed938e0> in <module>
# ----> 1 metrics.roc_auc_score(y_test, y_pred4, average=None)
#
# ~/Downloads/Rainfall_Prediction-Using-ML_Flask-master/rainfall/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/Downloads/Rainfall_Prediction-Using-ML_Flask-master/rainfall/lib/python3.6/site-packages/sklearn/metrics/_ranking.py in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     522     y_type = type_of_target(y_true)
#     523     y_true = check_array(y_true, ensure_2d=False, dtype=None)
# ...
